# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO("best.pt")
model.export(format="tflite", imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/angburmun/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.36 🚀 Python-3.12.3 torch-2.11.0+cu130 CPU (AMD Ryzen 7 5800X 8-Core Processor)
# YOLO11n summary (fused): 100 layers, 2,590,537 parameters, 0 gradients, 6.4 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 47, 8400) (5.2 MB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776284386.016474    1231 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
