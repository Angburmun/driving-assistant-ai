# %%
# %pip install -U ultralytics
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

model = YOLO("best.pt")
model.export(format="tflite", imgsz=640)
# Out:
# Ultralytics 8.4.62 🚀 Python-3.12.3 torch-2.11.0+cu130 CPU (AMD Ryzen 7 5800X 8-Core Processor)
# YOLO11n summary (fused): 101 layers, 2,586,442 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 26, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.21.0 opset 20...
# ONNX: slimming with onnxslim 0.1.91...
# ONNX: export success ✅ 3.4s, saved as 'best.onnx' (10.2 MB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780955333.588593   40265 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780955333.636336   40265 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
