# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.7 MB/s  0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.4.36
#     Uninstalling ultralytics-8.4.36:
#       Successfully uninstalled ultralytics-8.4.36
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from ultralytics import YOLO

# %%
DATA_YAML = "/mnt/d/TFM/Spanish traffic sign.v3-2025-07-06-8-30pm.yolov11/data.yaml"

# %%
model = YOLO("yolo11n.pt")

model.train(
    data=DATA_YAML,  
    epochs=100,
    imgsz=640,
    batch=16,
    device=0, 
    patience=20,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.49 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.36 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...
